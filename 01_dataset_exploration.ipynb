# %% [markdown]
# <a href="https://colab.research.google.com/github/nitesh742/northstar/blob/main/01_dataset_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("NorthStar Project Started")
# Out:
# NorthStar Project Started

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.listdir()
# Out:
# ['.config',
#  'deliveries.csv',
#  'orders.csv',
#  'hubs.csv',
#  'customers.csv',
#  'app_events.csv',
#  'data_dictionary.csv',
#  'complaints.csv',
#  'incidents.csv',
#  'vehicles.csv',
#  'README.txt',
#  'drivers.csv',
#  'sample_data']

# %%
df = pd.read_csv("customers.csv")

df.head()
# Out:
#   customer_id  age  home_zone customer_type          signup_date  \
# 0       C0001   26      North           SME  2024-11-27 04:25:00
# 1       C0002   61    AIRPORT      Consumer  2025-10-28 01:04:00
# 2       C0003   66       East      Consumer  2025-07-02 03:23:00
# 3       C0004   75    CENTRAL      Consumer  2025-08-19 01:58:00
# 4       C0005   26  Riverside      Consumer  2025-06-03 06:02:00
#
#    loyalty_score  app_engagement_score preferred_channel account_status
# 0           44.9                  69.2               App         Active
# 1           55.4                  66.6               App         Active
# 2           75.9                  33.8               NaN         Active
# 3           32.5                  33.0               App         Active
# 4           55.9                 100.0               Web         Active

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           650 non-null    object
#  1   age                   650 non-null    int64
#  2   home_zone             650 non-null    object
#  3   customer_type         650 non-null    object
#  4   signup_date           650 non-null    object
#  5   loyalty_score         630 non-null    float64
#  6   app_engagement_score  650 non-null    float64
#  7   preferred_channel     637 non-null    object
#  8   account_status        650 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 45.8+ KB

# %%
df.isnull().sum()
# Out:
# customer_id              0
# age                      0
# home_zone                0
# customer_type            0
# signup_date              0
# loyalty_score           20
# app_engagement_score     0
# preferred_channel       13
# account_status           0
# dtype: int64

# %%
df.describe()
# Out:
#               age  loyalty_score  app_engagement_score
# count  650.000000     630.000000            650.000000
# mean    46.738462      59.690635             58.132308
# std     17.449179      16.124674             18.918154
# min     18.000000      13.100000              1.000000
# 25%     32.000000      49.000000             45.375000
# 50%     46.000000      59.600000             59.000000
# 75%     62.000000      70.450000             72.000000
# max     78.000000      99.000000            100.000000

# %%
df['customer_id'].nunique()
# Out:
# 650

# %%
df['customer_type'].value_counts()
# Out:
# customer_type
# Consumer      476
# SME           124
# Enterprise     50
# Name: count, dtype: int64

# %%
df['home_zone'].value_counts()
# Out:
# home_zone
# SOUTH        50
# RiverSide    49
# East         48
# WEST         45
# CENTRAL      44
# West         43
# South        42
# Riverside    42
# EAST         41
# North        39
# north        39
# Airport      35
# AIRPORT      34
# Ctr          33
# NORTH        33
# Central      33
# Name: count, dtype: int64

# %%
zone_counts = df['home_zone'].value_counts()

zone_counts.plot(kind='bar')

plt.title("Customers by Home Zone")

plt.xlabel("Zone")

plt.ylabel("Number of Customers")

plt.show()

# %%
df['account_status'].value_counts()
# Out:
# account_status
# Active       552
# Dormant       78
# Suspended     20
# Name: count, dtype: int64

# %%
df[['age', 'loyalty_score', 'app_engagement_score']].corr()
# Out:
#                            age  loyalty_score  app_engagement_score
# age                   1.000000      -0.007273              0.022168
# loyalty_score        -0.007273       1.000000              0.035668
# app_engagement_score  0.022168       0.035668              1.000000

# %%
complaints = pd.read_csv("complaints.csv")

# %%
complaints.head()
# Out:
#   complaint_id customer_id order_id complaint_type  channel severity  \
# 0       CP0001       C0464   O00814       AppIssue      App     High
# 1       CP0002       C0056   O00628   MissedPickup    Phone   Medium
# 2       CP0003       C0469   O00384          Delay  Chatbot     High
# 3       CP0004       C0631   O00406          Delay      App   Medium
# 4       CP0005       C0535   O00154          Delay    Email   Medium
#
#             created_at            status  resolution_days  compensation_amount
# 0  2025-03-30 02:36:00              Open               11                23.99
# 1  2024-11-07 10:05:00              Open                4                21.64
# 2  2024-01-02 15:47:00              Open               16                26.41
# 3  2025-01-14 13:07:00  AwaitingCustomer                7                23.44
# 4  2024-08-31 05:56:00          Resolved                1                16.18

# %%
complaints.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   complaint_id         320 non-null    object
#  1   customer_id          320 non-null    object
#  2   order_id             320 non-null    object
#  3   complaint_type       320 non-null    object
#  4   channel              320 non-null    object
#  5   severity             320 non-null    object
#  6   created_at           320 non-null    object
#  7   status               320 non-null    object
#  8   resolution_days      320 non-null    int64
#  9   compensation_amount  304 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 25.1+ KB

# %%
complaints.isnull().sum()
# Out:
# complaint_id            0
# customer_id             0
# order_id                0
# complaint_type          0
# channel                 0
# severity                0
# created_at              0
# status                  0
# resolution_days         0
# compensation_amount    16
# dtype: int64

# %%
complaints.columns
# Out:
# Index(['complaint_id', 'customer_id', 'order_id', 'complaint_type', 'channel',
#        'severity', 'created_at', 'status', 'resolution_days',
#        'compensation_amount'],
#       dtype='object')

# %%
complaints['complaint_type'].value_counts()
# Out:
# complaint_type
# Delay                101
# MissedPickup          64
# AppIssue              53
# DriverBehaviour       51
# SupportExperience     20
# Billing               16
# Damage                15
# Name: count, dtype: int64

# %%
complaints['status'].value_counts()
# Out:
# status
# Resolved            186
# Open                 56
# AwaitingCustomer     40
# Escalated            38
# Name: count, dtype: int64

# %%
complaints.groupby('customer_id').size().sort_values(ascending=False).head(10)
# Out:
# customer_id
# C0368    4
# C0242    3
# C0191    3
# C0172    3
# C0282    3
# C0142    3
# C0421    3
# C0372    3
# C0110    3
# C0545    3
# dtype: int64

# %%
complaints['complaint_type'].value_counts().plot(kind='bar')

plt.title("Complaint Types Distribution")

plt.show()

# %%
merged.groupby('complaint_type')['loyalty_score'].mean()
# Out:
# complaint_type
# AppIssue             56.771429
# Billing              62.325000
# Damage               64.653333
# Delay                59.048980
# DriverBehaviour      61.939583
# MissedPickup         63.308065
# SupportExperience    57.352632
# Name: loyalty_score, dtype: float64

# %%
merged['home_zone'].value_counts()
# Out:
# home_zone
# SOUTH        33
# North        24
# RiverSide    24
# CENTRAL      24
# East         23
# Riverside    21
# north        21
# NORTH        19
# West         19
# Airport      19
# Ctr          18
# EAST         17
# South        17
# AIRPORT      15
# Central      14
# WEST         12
# Name: count, dtype: int64

# %%
merged.groupby('complaint_type')['app_engagement_score'].mean()
# Out:
# complaint_type
# AppIssue             59.477358
# Billing              62.875000
# Damage               48.906667
# Delay                55.516832
# DriverBehaviour      58.401961
# MissedPickup         55.051563
# SupportExperience    55.535000
# Name: app_engagement_score, dtype: float64

# %%
orders = pd.read_csv("orders.csv")

# %%
orders.head()
# Out:
#   order_id customer_id service_type     order_created_at  \
# 0   O00001       C0292    Passenger  2024-08-20 14:43:00
# 1   O00002       C0459    Passenger  2024-05-14 22:16:00
# 2   O00003       C0161    Passenger  2025-09-02 14:37:00
# 3   O00004       C0520       Parcel  2025-01-11 17:15:00
# 4   O00005       C0558       Retail  2025-02-17 19:32:00
#
#    promised_window_hours pickup_zone dropoff_zone priority_level  order_value  \
# 0                      6     Airport        South         Medium       126.65
# 1                     24       North      AIRPORT            Low       109.30
# 2                      4        West      AIRPORT           High        33.50
# 3                      2   RiverSide        North         Medium        10.04
# 4                     12   Riverside        SOUTH            Low       125.58
#
#   booking_channel  special_handling_flag
# 0             App                      0
# 1             App                      0
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1250 non-null   object
#  1   customer_id            1250 non-null   object
#  2   service_type           1250 non-null   object
#  3   order_created_at       1250 non-null   object
#  4   promised_window_hours  1250 non-null   int64
#  5   pickup_zone            1250 non-null   object
#  6   dropoff_zone           1250 non-null   object
#  7   priority_level         1250 non-null   object
#  8   order_value            1250 non-null   float64
#  9   booking_channel        1225 non-null   object
#  10  special_handling_flag  1250 non-null   int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 107.6+ KB

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# service_type              0
# order_created_at          0
# promised_window_hours     0
# pickup_zone               0
# dropoff_zone              0
# priority_level            0
# order_value               0
# booking_channel          25
# special_handling_flag     0
# dtype: int64

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'service_type', 'order_created_at',
#        'promised_window_hours', 'pickup_zone', 'dropoff_zone',
#        'priority_level', 'order_value', 'booking_channel',
#        'special_handling_flag'],
#       dtype='object')

# %%
orders['priority_level'].value_counts()
# Out:
# priority_level
# Medium      503
# Low         348
# High        308
# Critical     91
# Name: count, dtype: int64

# %%
orders.groupby('customer_id').size().head(10)
# Out:
# customer_id
# C0001    3
# C0002    1
# C0003    1
# C0004    3
# C0005    1
# C0006    3
# C0007    1
# C0009    1
# C0010    4
# C0012    3
# dtype: int64

# %%
deliveries = pd.read_csv("deliveries.csv")

# %%
deliveries.head()
# Out:
#   delivery_id order_id driver_id vehicle_id hub_id       dispatch_time  \
# 0     DL00001   O00938      D004       V056    H05 2024-06-18 10:57:00
# 1     DL00002   O00004      D138       V007    H02 2025-01-11 18:45:00
# 2     DL00003   O00639      D006       V049    H02 2025-06-02 20:39:00
# 3     DL00004   O00313      D116       V055    H02 2024-03-08 23:31:00
# 4     DL00005   O00844      D108       V034    H01 2025-09-21 11:43:00
#
#        delivery_completed_at delivery_status  route_distance_km  \
# 0 2024-06-19 09:05:59.904311          Failed              17.26
# 1 2025-01-11 17:39:00.000000          OnTime              10.34
# 2 2025-06-02 21:45:32.366770          OnTime               7.92
# 3 2024-03-09 23:30:08.103702         Delayed              16.42
# 4 2025-09-21 15:45:34.131056          OnTime              14.52
#
#    manual_route_override_count  proof_of_completion_missing  \
# 0                            1                            0
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   delivery_id                    950 non-null    object
#  1   order_id                       950 non-null    object
#  2   driver_id                      950 non-null    object
#  3   vehicle_id                     950 non-null    object
#  4   hub_id                         950 non-null    object
#  5   dispatch_time                  950 non-null    object
#  6   delivery_completed_at          931 non-null    object
#  7   delivery_status                950 non-null    object
#  8   route_distance_km              950 non-null    float64
#  9   manual_route_override_count    950 non-null    int64
#  10  proof_of_completion_missing    950 non-null    int64
#  11  customer_rating_post_delivery  936 non-null    float64
# ...

# %%
deliveries.isnull().sum()
# Out:
# delivery_id                       0
# order_id                          0
# driver_id                         0
# vehicle_id                        0
# hub_id                            0
# dispatch_time                     0
# delivery_completed_at            19
# delivery_status                   0
# route_distance_km                 0
# manual_route_override_count       0
# proof_of_completion_missing       0
# customer_rating_post_delivery    14
# fuel_or_charge_cost               0
# dtype: int64

# %%
deliveries.columns
# Out:
# Index(['delivery_id', 'order_id', 'driver_id', 'vehicle_id', 'hub_id',
#        'dispatch_time', 'delivery_completed_at', 'delivery_status',
#        'route_distance_km', 'manual_route_override_count',
#        'proof_of_completion_missing', 'customer_rating_post_delivery',
#        'fuel_or_charge_cost'],
#       dtype='object')

# %%
deliveries['delivery_status'].value_counts()
# Out:
# delivery_status
# OnTime     616
# Delayed    202
# Failed     132
# Name: count, dtype: int64

# %%
deliveries['delay_time'].mean()
# Out:
# np.float64(572.7291638523452)

# %%
order_delivery = pd.merge(orders, deliveries, on="order_id")

# %%
drivers = pd.read_csv("drivers.csv")

# %%
drivers.head()
drivers.info()
drivers.isnull().sum()
drivers.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   driver_id         170 non-null    object
#  1   base_zone         170 non-null    object
#  2   employment_type   170 non-null    object
#  3   years_experience  170 non-null    int64
#  4   training_score    163 non-null    float64
#  5   driver_rating     170 non-null    float64
#  6   shift_preference  170 non-null    object
#  7   active_flag       170 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 10.8+ KB
# Index(['driver_id', 'base_zone', 'employment_type', 'years_experience',
#        'training_score', 'driver_rating', 'shift_preference', 'active_flag'],
#       dtype='object')

# %%
drivers['driver_rating'].mean()
# Out:
# np.float64(4.171705882352941)

# %%
driver_perf = pd.merge(deliveries, drivers, on="driver_id")

# %%
vehicles = pd.read_csv("vehicles.csv")

# %%
vehicles.head()
vehicles.info()
vehicles.isnull().sum()
vehicles.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vehicle_id          120 non-null    object
#  1   vehicle_type        120 non-null    object
#  2   assigned_zone       120 non-null    object
#  3   commission_date     120 non-null    object
#  4   battery_health_pct  116 non-null    float64
#  5   odometer_km         120 non-null    int64
#  6   maintenance_status  120 non-null    object
#  7   telematics_version  120 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.6+ KB
# Index(['vehicle_id', 'vehicle_type', 'assigned_zone', 'commission_date',
#        'battery_health_pct', 'odometer_km', 'maintenance_status',
#        'telematics_version'],
#       dtype='object')

# %%
vehicles['maintenance_status'].value_counts()
# Out:
# maintenance_status
# Active       67
# InRepair     36
# Scheduled    17
# Name: count, dtype: int64

# %%
hubs = pd.read_csv("hubs.csv")

# %%
hubs.head()
hubs.info()
hubs.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hub_id          8 non-null      object
#  1   hub_name        8 non-null      object
#  2   zone            8 non-null      object
#  3   hub_type        8 non-null      object
#  4   capacity_score  8 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes
# Index(['hub_id', 'hub_name', 'zone', 'hub_type', 'capacity_score'], dtype='object')

# %%
hubs['zone'].value_counts()
# Out:
# zone
# Central      2
# South        1
# North        1
# East         1
# West         1
# Airport      1
# Riverside    1
# Name: count, dtype: int64

# %%
incidents = pd.read_csv("incidents.csv")

# %%
incidents.head()
incidents.info()
incidents.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   incident_id        280 non-null    object
#  1   delivery_id        280 non-null    object
#  2   incident_type      280 non-null    object
#  3   reported_at        280 non-null    object
#  4   severity           280 non-null    object
#  5   resolution_status  280 non-null    object
#  6   resolved_hours     263 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 15.4+ KB
# Index(['incident_id', 'delivery_id', 'incident_type', 'reported_at',
#        'severity', 'resolution_status', 'resolved_hours'],
#       dtype='object')

# %%
incidents['incident_type'].value_counts()
# Out:
# incident_type
# ProofMissing        46
# CustomerNoShow      44
# RouteDeviation      43
# VehicleFault        37
# BatteryAlert        36
# AppSyncError        31
# TemperatureIssue    29
# SafetyNearMiss      14
# Name: count, dtype: int64

# %%
app_events = pd.read_csv("app_events.csv")

# %%
app_events.head()
app_events.info()
app_events.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_id         640 non-null    object
#  1   customer_id      640 non-null    object
#  2   order_id         496 non-null    object
#  3   event_timestamp  640 non-null    object
#  4   event_type       640 non-null    object
#  5   session_id       640 non-null    object
#  6   device_type      640 non-null    object
#  7   zone_context     640 non-null    object
#  8   api_latency_ms   640 non-null    int64
#  9   success_flag     640 non-null    int64
# dtypes: int64(2), object(8)
# memory usage: 50.1+ KB
# Index(['event_id', 'customer_id', 'order_id', 'event_timestamp', 'event_type',
#        'session_id', 'device_type', 'zone_context', 'api_latency_ms',
#        'success_flag'],
#       dtype='object')

# %%
app_events['event_type'].value_counts()
# Out:
# event_type
# track_order                    138
# eta_refresh                    105
# search_route                    99
# chat_opened                     88
# delivery_instruction_update     75
# payment_retry                   69
# chat_escalated                  38
# cancel_attempt                  28
# Name: count, dtype: int64

# %%
data_dict = pd.read_csv("data_dictionary.csv")

# %%
data_dict.head()
data_dict.info()
data_dict.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   file_name     9 non-null      object
#  1   record_count  9 non-null      int64
#  2   description   9 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 348.0+ bytes
# Index(['file_name', 'record_count', 'description'], dtype='object')

# %%
incidents.columns
deliveries.columns
# Out:
# Index(['delivery_id', 'order_id', 'driver_id', 'vehicle_id', 'hub_id',
#        'dispatch_time', 'delivery_completed_at', 'delivery_status',
#        'route_distance_km', 'manual_route_override_count',
#        'proof_of_completion_missing', 'customer_rating_post_delivery',
#        'fuel_or_charge_cost', 'delay_time'],
#       dtype='object')

# %%
inc_del = pd.merge(deliveries, incidents, on="delivery_id", how="left")

# %%
full = orders.merge(deliveries, on="order_id") \
             .merge(inc_del, on="delivery_id", how="left")

# %%
full = full.merge(customers, on="customer_id")

# %%
full.groupby("hub_id_x")["delay_time_x"].mean()
# Out:
# hub_id_x
# H01    560.528101
# H02    518.218642
# H03    453.830355
# H04    620.036422
# H05    645.688122
# H06    554.721237
# H07    589.152359
# H08    583.098549
# Name: delay_time_x, dtype: float64

# %%
complaints.merge(customers, on="customer_id") \
           .groupby("complaint_type")["loyalty_score"].mean()
# Out:
# complaint_type
# AppIssue             56.771429
# Billing              62.325000
# Damage               64.653333
# Delay                59.048980
# DriverBehaviour      61.939583
# MissedPickup         63.308065
# SupportExperience    57.352632
# Name: loyalty_score, dtype: float64

# %%
driver_perf.groupby("driver_id")["delay_time"].mean()
# Out:
# driver_id
# D001    1033.714714
# D002     396.519930
# D003     263.573036
# D004     569.040295
# D005     464.221695
#            ...
# D166     277.744161
# D167     863.825688
# D168     361.965308
# D169      98.002251
# D170    1035.455767
# Name: delay_time, Length: 170, dtype: float64

# %%
incidents['severity'].value_counts()
# Out:
# severity
# Medium      106
# Low          79
# High         68
# Critical     27
# Name: count, dtype: int64

# %%
orders.head()
deliveries.head()
# Out:
#   delivery_id order_id driver_id vehicle_id hub_id       dispatch_time  \
# 0     DL00001   O00938      D004       V056    H05 2024-06-18 10:57:00
# 1     DL00002   O00004      D138       V007    H02 2025-01-11 18:45:00
# 2     DL00003   O00639      D006       V049    H02 2025-06-02 20:39:00
# 3     DL00004   O00313      D116       V055    H02 2024-03-08 23:31:00
# 4     DL00005   O00844      D108       V034    H01 2025-09-21 11:43:00
#
#        delivery_completed_at delivery_status  route_distance_km  \
# 0 2024-06-19 09:05:59.904311          Failed              17.26
# 1 2025-01-11 17:39:00.000000          OnTime              10.34
# 2 2025-06-02 21:45:32.366770          OnTime               7.92
# 3 2024-03-09 23:30:08.103702         Delayed              16.42
# 4 2025-09-21 15:45:34.131056          OnTime              14.52
#
#    manual_route_override_count  proof_of_completion_missing  \
# 0                            1                            0
# ...

# %%
orders.columns
deliveries.columns
# Out:
# Index(['delivery_id', 'order_id', 'driver_id', 'vehicle_id', 'hub_id',
#        'dispatch_time', 'delivery_completed_at', 'delivery_status',
#        'route_distance_km', 'manual_route_override_count',
#        'proof_of_completion_missing', 'customer_rating_post_delivery',
#        'fuel_or_charge_cost', 'delay_time'],
#       dtype='object')

# %%
order_delivery = pd.merge(orders, deliveries, on="order_id", how="inner")

# %%
order_delivery.isnull().sum()
# Out:
# order_id                          0
# customer_id                       0
# service_type                      0
# order_created_at                  0
# promised_window_hours             0
# pickup_zone                       0
# dropoff_zone                      0
# priority_level                    0
# order_value                       0
# booking_channel                  21
# special_handling_flag             0
# delivery_id                       0
# driver_id                         0
# vehicle_id                        0
# hub_id                            0
# dispatch_time                     0
# delivery_completed_at            19
# delivery_status                   0
# route_distance_km                 0
# manual_route_override_count       0
# proof_of_completion_missing       0
# customer_rating_post_delivery    14
# fuel_or_charge_cost               0
# delay_time                       19
# dtype: int64

# %%
order_delivery['delivery_status'].value_counts()
# Out:
# delivery_status
# OnTime     616
# Delayed    202
# Failed     132
# Name: count, dtype: int64

# %%
order_delivery['delay_time'].mean()
# Out:
# np.float64(572.7291638523452)

# %%
order_delivery['hub_id'].value_counts()
# Out:
# hub_id
# H01    136
# H08    128
# H04    127
# H03    119
# H07    115
# H05    115
# H02    106
# H06    104
# Name: count, dtype: int64

# %%
pd.merge(order_delivery, customers, on="customer_id")
# Out:
#     order_id customer_id service_type     order_created_at  \
# 0     O00001       C0292    Passenger  2024-08-20 14:43:00
# 1     O00003       C0161    Passenger  2025-09-02 14:37:00
# 2     O00004       C0520       Parcel  2025-01-11 17:15:00
# 3     O00005       C0558       Retail  2025-02-17 19:32:00
# 4     O00007       C0001     Business  2024-05-05 21:32:00
# ..       ...         ...          ...                  ...
# 945   O01245       C0237       Retail  2025-10-05 14:03:00
# 946   O01246       C0198     Business  2024-04-04 00:51:00
# 947   O01248       C0517       Retail  2024-08-30 17:16:00
# 948   O01249       C0572      Medical  2024-08-25 16:52:00
# 949   O01250       C0180       Retail  2024-06-28 07:38:00
#
#      promised_window_hours pickup_zone dropoff_zone priority_level  \
# 0                        6     Airport        South         Medium
# 1                        4        West      AIRPORT           High
# ...

# %%
orders.columns
deliveries.columns
# Out:
# Index(['delivery_id', 'order_id', 'driver_id', 'vehicle_id', 'hub_id',
#        'dispatch_time', 'delivery_completed_at', 'delivery_status',
#        'route_distance_km', 'manual_route_override_count',
#        'proof_of_completion_missing', 'customer_rating_post_delivery',
#        'fuel_or_charge_cost', 'delay_time'],
#       dtype='object')

# %%
orders.columns
deliveries.columns
# Out:
# Index(['delivery_id', 'order_id', 'driver_id', 'vehicle_id', 'hub_id',
#        'dispatch_time', 'delivery_completed_at', 'delivery_status',
#        'route_distance_km', 'manual_route_override_count',
#        'proof_of_completion_missing', 'customer_rating_post_delivery',
#        'fuel_or_charge_cost', 'delay_time'],
#       dtype='object')

# %%
orders['order_id'].nunique()
deliveries['order_id'].nunique()
# Out:
# 950

# %%
order_delivery = pd.merge(orders, deliveries, on="order_id", how="inner")

# %%
order_delivery.head()
# Out:
#   order_id customer_id service_type     order_created_at  \
# 0   O00001       C0292    Passenger  2024-08-20 14:43:00
# 1   O00003       C0161    Passenger  2025-09-02 14:37:00
# 2   O00004       C0520       Parcel  2025-01-11 17:15:00
# 3   O00005       C0558       Retail  2025-02-17 19:32:00
# 4   O00007       C0001     Business  2024-05-05 21:32:00
#
#    promised_window_hours pickup_zone dropoff_zone priority_level  order_value  \
# 0                      6     Airport        South         Medium       126.65
# 1                      4        West      AIRPORT           High        33.50
# 2                      2   RiverSide        North         Medium        10.04
# 3                     12   Riverside        SOUTH            Low       125.58
# 4                      2     CENTRAL      Airport            Low        76.12
#
#   booking_channel  ...  hub_id       dispatch_time      delivery_completed_at  \
# ...

# %%
order_delivery.isnull().sum()
# Out:
# order_id                          0
# customer_id                       0
# service_type                      0
# order_created_at                  0
# promised_window_hours             0
# pickup_zone                       0
# dropoff_zone                      0
# priority_level                    0
# order_value                       0
# booking_channel                  21
# special_handling_flag             0
# delivery_id                       0
# driver_id                         0
# vehicle_id                        0
# hub_id                            0
# dispatch_time                     0
# delivery_completed_at            19
# delivery_status                   0
# route_distance_km                 0
# manual_route_override_count       0
# proof_of_completion_missing       0
# customer_rating_post_delivery    14
# fuel_or_charge_cost               0
# delay_time                       19
# dtype: int64

# %%
order_delivery['delivery_status'].value_counts()
order_delivery['hub_id'].value_counts()
# Out:
# hub_id
# H01    136
# H08    128
# H04    127
# H03    119
# H07    115
# H05    115
# H02    106
# H06    104
# Name: count, dtype: int64

# %%
order_delivery['delay_time'].mean()
# Out:
# np.float64(572.7291638523452)

# %%
full = order_delivery.merge(customers, on="customer_id")
full = full.merge(drivers, on="driver_id")

# %%
full = full.merge(incidents, on="delivery_id", how="left")

# %%
order_delivery = pd.merge(orders, deliveries, on="order_id")
order_delivery.head()
# Out:
#   order_id customer_id service_type     order_created_at  \
# 0   O00001       C0292    Passenger  2024-08-20 14:43:00
# 1   O00003       C0161    Passenger  2025-09-02 14:37:00
# 2   O00004       C0520       Parcel  2025-01-11 17:15:00
# 3   O00005       C0558       Retail  2025-02-17 19:32:00
# 4   O00007       C0001     Business  2024-05-05 21:32:00
#
#    promised_window_hours pickup_zone dropoff_zone priority_level  order_value  \
# 0                      6     Airport        South         Medium       126.65
# 1                      4        West      AIRPORT           High        33.50
# 2                      2   RiverSide        North         Medium        10.04
# 3                     12   Riverside        SOUTH            Low       125.58
# 4                      2     CENTRAL      Airport            Low        76.12
#
#   booking_channel  ...  hub_id       dispatch_time      delivery_completed_at  \
# ...

# %%
order_delivery.info()
order_delivery.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       950 non-null    object
#  1   customer_id                    950 non-null    object
#  2   service_type                   950 non-null    object
#  3   order_created_at               950 non-null    object
#  4   promised_window_hours          950 non-null    int64
#  5   pickup_zone                    950 non-null    object
#  6   dropoff_zone                   950 non-null    object
#  7   priority_level                 950 non-null    object
#  8   order_value                    950 non-null    float64
#  9   booking_channel                929 non-null    object
#  10  special_handling_flag          950 non-null    int64
#  11  delivery_id                    950 non-null    object
# ...

# %%
order_delivery['delivery_status'].value_counts()
# Out:
# delivery_status
# OnTime     616
# Delayed    202
# Failed     132
# Name: count, dtype: int64

# %%
order_delivery['delay_time'].mean()
# Out:
# np.float64(572.7291638523452)

# %%
order_delivery.groupby('hub_id')['delay_time'].mean().sort_values(ascending=False)
# Out:
# hub_id
# H05    654.248030
# H04    619.829453
# H07    595.113258
# H08    589.150707
# H01    562.902086
# H06    562.758006
# H02    532.024348
# H03    459.414852
# Name: delay_time, dtype: float64

# %%
order_delivery.groupby('pickup_zone')['delay_time'].mean().sort_values(ascending=False)
# Out:
# pickup_zone
# RiverSide    687.619243
# CENTRAL      647.275564
# Ctr          644.653140
# EAST         628.899623
# NORTH        615.762713
# South        601.180219
# Central      600.473900
# WEST         567.102423
# AIRPORT      549.872275
# north        536.109314
# Airport      531.441637
# East         528.815380
# West         517.263547
# Riverside    496.076244
# North        495.075457
# SOUTH        444.928823
# Name: delay_time, dtype: float64

# %%
order_delivery.groupby('manual_route_override_count')['delay_time'].mean()
# Out:
# manual_route_override_count
# 0     583.461679
# 1     574.491035
# 2     552.616352
# 3     521.001870
# 4     588.370709
# 5     594.069666
# 7    1293.135841
# Name: delay_time, dtype: float64

# %%
order_delivery.groupby('delivery_status')['customer_rating_post_delivery'].mean()
# Out:
# delivery_status
# Delayed    3.114975
# Failed     3.049313
# OnTime     4.283273
# Name: customer_rating_post_delivery, dtype: float64

# %%
order_delivery.groupby('hub_id')['delay_time'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='hub_id'>

# %%
order_delivery['delivery_status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='delivery_status'>

# %%
order_delivery.plot.scatter(x='route_distance_km', y='delay_time')
# Out:
# <Axes: xlabel='route_distance_km', ylabel='delay_time'>

# %%
incidents.head()
complaints.head()
# Out:
#   complaint_id customer_id order_id complaint_type  channel severity  \
# 0       CP0001       C0464   O00814       AppIssue      App     High
# 1       CP0002       C0056   O00628   MissedPickup    Phone   Medium
# 2       CP0003       C0469   O00384          Delay  Chatbot     High
# 3       CP0004       C0631   O00406          Delay      App   Medium
# 4       CP0005       C0535   O00154          Delay    Email   Medium
#
#             created_at            status  resolution_days  compensation_amount
# 0  2025-03-30 02:36:00              Open               11                23.99
# 1  2024-11-07 10:05:00              Open                4                21.64
# 2  2024-01-02 15:47:00              Open               16                26.41
# 3  2025-01-14 13:07:00  AwaitingCustomer                7                23.44
# 4  2024-08-31 05:56:00          Resolved                1                16.18

# %%
complaints.info()
complaints.isnull().sum()
complaints['complaint_type'].value_counts()
complaints['status'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   complaint_id         320 non-null    object
#  1   customer_id          320 non-null    object
#  2   order_id             320 non-null    object
#  3   complaint_type       320 non-null    object
#  4   channel              320 non-null    object
#  5   severity             320 non-null    object
#  6   created_at           320 non-null    object
#  7   status               320 non-null    object
#  8   resolution_days      320 non-null    int64
#  9   compensation_amount  304 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 25.1+ KB
# status
# Resolved            186
# Open                 56
# AwaitingCustomer     40
# Escalated            38
# Name: count, dtype: int64

# %%
complaints['complaint_type'].value_counts()
# Out:
# complaint_type
# Delay                101
# MissedPickup          64
# AppIssue              53
# DriverBehaviour       51
# SupportExperience     20
# Billing               16
# Damage                15
# Name: count, dtype: int64

# %%
complaints['severity'].value_counts()
# Out:
# severity
# Medium    172
# High       77
# Low        71
# Name: count, dtype: int64

# %%
complaints['resolution_days'].mean()
# Out:
# np.float64(7.928125)

# %%
complaints['compensation_amount'].sum()
# Out:
# np.float64(6158.1900000000005)

# %%
complaints_cust = complaints.merge(customers, on="customer_id")

# %%
complaints_cust.groupby('customer_type').size()
complaints_cust.groupby('complaint_type')['loyalty_score'].mean()
complaints_orders = complaints.merge(order_delivery, on="order_id")
complaints_orders.groupby('complaint_type')['delay_time'].mean()
complaints_orders.groupby('complaint_type')['customer_rating_post_delivery'].mean()
# Out:
# complaint_type
# AppIssue             3.935278
# Billing              3.380833
# Damage               4.276364
# Delay                3.866667
# DriverBehaviour      4.026842
# MissedPickup         4.023488
# SupportExperience    3.762353
# Name: customer_rating_post_delivery, dtype: float64

# %%
complaints['complaint_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='complaint_type'>

# %%
complaints['severity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='severity'>

# %%
complaints.groupby('complaint_type')['compensation_amount'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='complaint_type'>

# %%
incidents.head()
# Out:
#   incident_id delivery_id     incident_type          reported_at severity  \
# 0       I0001     DL00221      BatteryAlert  2024-03-11 23:46:00   Medium
# 1       I0002     DL00578      BatteryAlert  2024-02-21 10:56:00      Low
# 2       I0003     DL00175  TemperatureIssue  2025-04-17 23:22:00   Medium
# 3       I0004     DL00417      ProofMissing  2025-02-09 00:16:00   Medium
# 4       I0005     DL00897    RouteDeviation  2025-01-04 02:49:00      Low
#
#   resolution_status  resolved_hours
# 0         Escalated            12.3
# 1              Open             9.6
# 2              Open            22.0
# 3            Closed             9.8
# 4              Open            13.0

# %%
drivers.head()
# Out:
#   driver_id base_zone employment_type  years_experience  training_score  \
# 0      D001   AIRPORT        FullTime                 8            67.8
# 1      D002   Central        FullTime                 4            42.4
# 2      D003   AIRPORT        FullTime                11            96.5
# 3      D004   Airport        PartTime                13            88.9
# 4      D005     north        FullTime                 3            69.7
#
#    driver_rating shift_preference  active_flag
# 0           3.54          Morning            1
# 1           3.94          Evening            1
# 2           5.00          Evening            1
# 3           4.75          Morning            1
# 4           4.14          Morning            1

# %%
vehicles.head()
# Out:
#   vehicle_id vehicle_type assigned_zone      commission_date  \
# 0       V001           EV         North  2024-12-28 23:48:00
# 1       V002           EV       AIRPORT  2024-04-21 16:14:00
# 2       V003     CargoVan         north  2025-11-24 23:59:00
# 3       V004       Hybrid     RiverSide  2024-06-07 13:21:00
# 4       V005     CargoVan          West  2025-11-15 11:08:00
#
#    battery_health_pct  odometer_km maintenance_status telematics_version
# 0                71.8        56928             Active               v2.2
# 1                67.9       159368           InRepair               v2.2
# 2                91.7       219359             Active               v2.1
# 3                 NaN        36310             Active               v2.2
# 4                58.6       146638             Active               v2.2

# %%
import sqlite3

# %%
conn = sqlite3.connect("logistics.db")

# %%
customers.to_sql("customers", conn, if_exists="replace", index=False)
orders.to_sql("orders", conn, if_exists="replace", index=False)
deliveries.to_sql("deliveries", conn, if_exists="replace", index=False)
drivers.to_sql("drivers", conn, if_exists="replace", index=False)
vehicles.to_sql("vehicles", conn, if_exists="replace", index=False)
hubs.to_sql("hubs", conn, if_exists="replace", index=False)
incidents.to_sql("incidents", conn, if_exists="replace", index=False)
complaints.to_sql("complaints", conn, if_exists="replace", index=False)
# Out:
# 320

# %%
import pandas as pd

# %%
pd.read_sql_query("""
SELECT * FROM customers LIMIT 5
""", conn)
# Out:
#   customer_id  age  home_zone customer_type          signup_date  \
# 0       C0001   26      North           SME  2024-11-27 04:25:00
# 1       C0002   61    AIRPORT      Consumer  2025-10-28 01:04:00
# 2       C0003   66       East      Consumer  2025-07-02 03:23:00
# 3       C0004   75    CENTRAL      Consumer  2025-08-19 01:58:00
# 4       C0005   26  Riverside      Consumer  2025-06-03 06:02:00
#
#    loyalty_score  app_engagement_score preferred_channel account_status
# 0           44.9                  69.2               App         Active
# 1           55.4                  66.6               App         Active
# 2           75.9                  33.8              None         Active
# 3           32.5                  33.0               App         Active
# 4           55.9                 100.0               Web         Active

# %%
pd.read_sql_query("""
SELECT customer_id, COUNT(order_id) AS total_orders
FROM orders
GROUP BY customer_id
ORDER BY total_orders DESC
""", conn)
# Out:
#     customer_id  total_orders
# 0         C0343             7
# 1         C0622             6
# 2         C0599             6
# 3         C0545             6
# 4         C0478             6
# ..          ...           ...
# 563       C0009             1
# 564       C0007             1
# 565       C0005             1
# 566       C0003             1
# 567       C0002             1
#
# [568 rows x 2 columns]

# %%
pd.read_sql_query("""
SELECT
    o.order_id,
    c.customer_id,
    d.delivery_status,
    d.delay_time
FROM orders o
JOIN customers c ON o.customer_id = c.customer_id
JOIN deliveries d ON o.order_id = d.order_id
""", conn)
# Out:
#     order_id customer_id delivery_status   delay_time
# 0     O00001       C0292          OnTime   143.936203
# 1     O00003       C0161         Delayed   531.660745
# 2     O00004       C0520          OnTime   -66.000000
# 3     O00005       C0558          OnTime   702.000785
# 4     O00007       C0001         Delayed   535.292587
# ..       ...         ...             ...          ...
# 945   O01245       C0237          OnTime   -97.000000
# 946   O01246       C0198          Failed   445.974710
# 947   O01248       C0517          OnTime  1220.023304
# 948   O01249       C0572         Delayed   519.701444
# 949   O01250       C0180         Delayed   335.867331
#
# [950 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM orders LIMIT 5", conn)
# Out:
#   order_id customer_id service_type     order_created_at  \
# 0   O00001       C0292    Passenger  2024-08-20 14:43:00
# 1   O00002       C0459    Passenger  2024-05-14 22:16:00
# 2   O00003       C0161    Passenger  2025-09-02 14:37:00
# 3   O00004       C0520       Parcel  2025-01-11 17:15:00
# 4   O00005       C0558       Retail  2025-02-17 19:32:00
#
#    promised_window_hours pickup_zone dropoff_zone priority_level  order_value  \
# 0                      6     Airport        South         Medium       126.65
# 1                     24       North      AIRPORT            Low       109.30
# 2                      4        West      AIRPORT           High        33.50
# 3                      2   RiverSide        North         Medium        10.04
# 4                     12   Riverside        SOUTH            Low       125.58
#
#   booking_channel  special_handling_flag
# 0             App                      0
# 1             App                      0
# ...

# %%
customers.head()
orders.head()
deliveries.head()
# Out:
#   delivery_id order_id driver_id vehicle_id hub_id       dispatch_time  \
# 0     DL00001   O00938      D004       V056    H05 2024-06-18 10:57:00
# 1     DL00002   O00004      D138       V007    H02 2025-01-11 18:45:00
# 2     DL00003   O00639      D006       V049    H02 2025-06-02 20:39:00
# 3     DL00004   O00313      D116       V055    H02 2024-03-08 23:31:00
# 4     DL00005   O00844      D108       V034    H01 2025-09-21 11:43:00
#
#        delivery_completed_at delivery_status  route_distance_km  \
# 0 2024-06-19 09:05:59.904311          Failed              17.26
# 1 2025-01-11 17:39:00.000000          OnTime              10.34
# 2 2025-06-02 21:45:32.366770          OnTime               7.92
# 3 2024-03-09 23:30:08.103702         Delayed              16.42
# 4 2025-09-21 15:45:34.131056          OnTime              14.52
#
#    manual_route_override_count  proof_of_completion_missing  \
# 0                            1                            0
# ...

# %%
orders.info()
orders.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1250 non-null   object
#  1   customer_id            1250 non-null   object
#  2   service_type           1250 non-null   object
#  3   order_created_at       1250 non-null   object
#  4   promised_window_hours  1250 non-null   int64
#  5   pickup_zone            1250 non-null   object
#  6   dropoff_zone           1250 non-null   object
#  7   priority_level         1250 non-null   object
#  8   order_value            1250 non-null   float64
#  9   booking_channel        1225 non-null   object
#  10  special_handling_flag  1250 non-null   int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 107.6+ KB
# order_id                  0
# customer_id               0
# service_type              0
# order_created_at          0
# ...
